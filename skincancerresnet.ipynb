# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2026-01-03 21:54:44.314230: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767477284.465023      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767477284.509332      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767477284.863690      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767477284.863750      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767477284.863756      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767477284.863761      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ## Loading Images

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
path = '/kaggle/input/skin-dataset/data/train/malignant'
name = '2.jpg'
fullname = path + '/' + name
load_img(fullname)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %% [markdown]
# Usually we resize images. This is how a network will see these images:

# %%
load_img(fullname, target_size=(299, 299))
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
load_img(fullname, target_size=(150, 150))
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %% [markdown]
# ## Pre-Trained Neural Network

# %% [markdown]
# Let's apply a pre-trained neural network with imagenet classes.
#
# We'll use ResNet, but any other architecture will work as well.
#
# Check here for a list of available models:
#
# * https://keras.io/api/applications/
# * https://www.tensorflow.org/api_docs/python/tf/keras/applications
#
#
# We'll need to import 3 things:
#
# * the model itself (`Xception`)
# * the `preprocess_input` function that takes an image and prepares it
# * the `decode_predictions` that converts the predictions of the model into human-readable classes

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet50 import decode_predictions

# %% [markdown]
# Let's load the model. The pre-trained model expects 299x299 input

# %%
model = ResNet50(
    weights='imagenet',
    input_shape=(224, 224, 3)
)
# Out:
# I0000 00:00:1767477297.424251      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# Next,
#
# * we load the image using the `load_img` function
# * convert it to a numpy array
# * make it a batch of one example

# %%
img = load_img(fullname, target_size=(224, 224))
x = np.array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
X = np.array([x])
X.shape
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# We're ready!
#
# Next, we will:
#
# * prepare the input
# * do the predictions
# * convert the predictions into a human-readable format

# %%
X = preprocess_input(X)

# %%
pred = model.predict(X)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767477305.612281      70 service.cc:152] XLA service 0x7ad308004e30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767477305.612315      70 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1767477306.385413      70 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# I0000 00:00:1767477308.853687      70 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
pred.shape
# Out:
# (1, 1000)

# %%
pred[0, :10]
# Out:
# array([1.36078515e-05, 2.96396727e-04, 1.42505616e-01, 1.90793537e-02,
#        2.67663714e-03, 1.19561562e-02, 1.38734384e-02, 1.10433184e-05,
#        3.70980451e-05, 5.28533419e-05], dtype=float32)

# %%
decode_predictions(pred)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n01484850', 'great_white_shark', np.float32(0.14250562)),
#   ('n03920288', 'Petri_dish', np.float32(0.14159971)),
#   ('n07734744', 'mushroom', np.float32(0.106266305)),
#   ('n02219486', 'ant', np.float32(0.07031407)),
#   ('n02799071', 'baseball', np.float32(0.06872797))]]

# %% [markdown]
# Not quite what we wanted... Let's train our own model

# %% [markdown]
# ## Transfer learning

# %% [markdown]
# Instead of loading each image one-by-one, we can use a data generator. Keras will use it for loading the images and pre-processing them

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# We'll use smaller images - it'll be faster

# %%
image_size = (150, 150)
batch_size = 32

# %% [markdown]
# Let's get train data:

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_ds = train_gen.flow_from_directory(
    "/kaggle/input/skin-dataset/data/train",
    seed=1,
    target_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2637 images belonging to 2 classes.

# %% [markdown]
# And validation:

# %%
test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_ds = test_gen.flow_from_directory(
    "/kaggle/input/skin-dataset/data/test",
    seed=1,
    target_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 660 images belonging to 2 classes.

# %% [markdown]
# For fine-tuning, we'll use `Xception` with small images (150x150)

# %%
base_model = ResNet50(
    weights='imagenet',
    input_shape=(150, 150, 3),
    include_top=False
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# Let's add a small neural net on top of that: just one layer with 10 neurons (there are 10 classes we want to predict)

# %%
inputs = keras.Input(shape=(150, 150, 3))

base = base_model(inputs, training=False)
vector = keras.layers.GlobalAveragePooling2D()(base)
outputs = keras.layers.Dense(2)(vector)

model = keras.Model(inputs, outputs)

# %% [markdown]
# Now we specify the learning rate and compile the model. After that, it's ready for training

# %%
learning_rate = 0.01

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

# %% [markdown]
# Let's train now for 10 epochs:

# %%
history = model.fit(train_ds, epochs=20, validation_data=test_ds)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 314ms/step - accuracy: 0.7225 - loss: 1.5741 - val_accuracy: 0.8470 - val_loss: 0.5529
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.8300 - loss: 0.5675 - val_accuracy: 0.8485 - val_loss: 0.5138
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - accuracy: 0.8854 - loss: 0.3310 - val_accuracy: 0.8379 - val_loss: 0.5333
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.8833 - loss: 0.3613 - val_accuracy: 0.8545 - val_loss: 0.4986
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - accuracy: 0.8860 - loss: 0.3375 - val_accuracy: 0.8636 - val_loss: 0.6250
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9071 - loss: 0.2611 - val_accuracy: 0.8485 - val_loss: 0.7580
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.8953 - loss: 0.3428 - val_accuracy: 0.8591 - val_loss: 0.7701
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9091 - loss: 0.3033 - val_accuracy: 0.8727 - val_loss: 0.5142
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 0.9391 - loss: 0.1715 - val_accuracy: 0.8909 - val_loss: 0.5983
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9262 - loss: 0.2222 - val_accuracy: 0.8788 - val_loss: 0.5015
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9557 - loss: 0.1297 - val_accuracy: 0.8848 - val_loss: 0.5314
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9285 - loss: 0.1989 - val_accuracy: 0.7758 - val_loss: 1.3718
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9090 - loss: 0.2857 - val_accuracy: 0.8530 - val_loss: 0.7743
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.9457 - loss: 0.1534 - val_accuracy: 0.8636 - val_loss: 0.6737
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9632 - loss: 0.1004 - val_accuracy: 0.8758 - val_loss: 0.6004
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - accuracy: 0.9559 - loss: 0.1184 - val_accuracy: 0.8561 - val_loss: 0.6840
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.9680 - loss: 0.0960 - val_accuracy: 0.7879 - val_loss: 1.5743
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9243 - loss: 0.2396 - val_accuracy: 0.8727 - val_loss: 0.6526
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9453 - loss: 0.1579 - val_accuracy: 0.8667 - val_loss: 0.6584
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.9684 - loss: 0.0877 - val_accuracy: 0.8652 - val_loss: 0.7098

# %%
plt.figure(figsize=(6, 4))

epochs = history.epoch
val = history.history['val_accuracy']
train = history.history['accuracy']

plt.plot(epochs, val, color='black', linestyle='solid', label='validation')
plt.plot(epochs, train, color='black', linestyle='dashed', label='train')

plt.title('ResNet50, lr=0.01')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.xticks(np.arange(10))

plt.legend()


plt.savefig('resnet_v1_0_01.svg')

plt.show()

# %% [markdown]
# 0.01 is not necessarily the best learning rate, so we should experiment with 0.001 and 0.0001.
#
# To make it easier for us, let's make a function for defining our model:

# %%
def make_model(learning_rate):
    base_model = ResNet50(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(150, 150, 3))

    base = base_model(inputs, training=False)
    vector = keras.layers.GlobalAveragePooling2D()(base)
    outputs = keras.layers.Dense(2)(vector)

    model = keras.Model(inputs, outputs)
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    
    return model

# %% [markdown]
# Watching metrics this way is not convenient, so let's create a special callback for that

# %%
model = make_model(learning_rate=0.001)
history_0_001 = model.fit(train_ds, epochs=20, validation_data=test_ds)
# Out:
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 187ms/step - accuracy: 0.7568 - loss: 0.5118 - val_accuracy: 0.8364 - val_loss: 0.3424
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.8567 - loss: 0.3306 - val_accuracy: 0.8576 - val_loss: 0.3085
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.8813 - loss: 0.2655 - val_accuracy: 0.8561 - val_loss: 0.3019
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.8994 - loss: 0.2369 - val_accuracy: 0.8652 - val_loss: 0.3236
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.9004 - loss: 0.2360 - val_accuracy: 0.8803 - val_loss: 0.2794
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9128 - loss: 0.2082 - val_accuracy: 0.8833 - val_loss: 0.2881
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9109 - loss: 0.2031 - val_accuracy: 0.9015 - val_loss: 0.2765
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9263 - loss: 0.1818 - val_accuracy: 0.8773 - val_loss: 0.2797
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9230 - loss: 0.1885 - val_accuracy: 0.8515 - val_loss: 0.3144
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9097 - loss: 0.1959 - val_accuracy: 0.8833 - val_loss: 0.2800
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9346 - loss: 0.1657 - val_accuracy: 0.8788 - val_loss: 0.3262
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9212 - loss: 0.1694 - val_accuracy: 0.8742 - val_loss: 0.2862
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9376 - loss: 0.1583 - val_accuracy: 0.8803 - val_loss: 0.2864
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9452 - loss: 0.1364 - val_accuracy: 0.8758 - val_loss: 0.3204
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9488 - loss: 0.1447 - val_accuracy: 0.8621 - val_loss: 0.3021
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9458 - loss: 0.1486 - val_accuracy: 0.8909 - val_loss: 0.2931
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9345 - loss: 0.1493 - val_accuracy: 0.8879 - val_loss: 0.2872
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9358 - loss: 0.1472 - val_accuracy: 0.8864 - val_loss: 0.2874
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9539 - loss: 0.1186 - val_accuracy: 0.8894 - val_loss: 0.2917
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9438 - loss: 0.1370 - val_accuracy: 0.8848 - val_loss: 0.2900

# %%
plt.figure(figsize=(6, 4))

epochs = history_0_001.epoch
val = history_0_001.history['val_accuracy']
train = history_0_001.history['accuracy']

plt.plot(epochs, val, color='black', linestyle='solid', label='validation')
plt.plot(epochs, train, color='black', linestyle='dashed', label='train')

plt.title('ResNet v1, lr=0.001')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.xticks(epochs)

plt.legend()


plt.savefig('resnet_v1_0_001.svg')

plt.show()

# %%
model = make_model(learning_rate=0.0001)
history_0_0001 = model.fit(train_ds, epochs=20, validation_data=test_ds)
# Out:
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 187ms/step - accuracy: 0.5760 - loss: 0.8059 - val_accuracy: 0.7409 - val_loss: 0.5492
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.7647 - loss: 0.5127 - val_accuracy: 0.7818 - val_loss: 0.4576
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.7995 - loss: 0.4400 - val_accuracy: 0.8030 - val_loss: 0.4158
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.8175 - loss: 0.4059 - val_accuracy: 0.8182 - val_loss: 0.3945
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8386 - loss: 0.3787 - val_accuracy: 0.8288 - val_loss: 0.3786
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8381 - loss: 0.3698 - val_accuracy: 0.8364 - val_loss: 0.3679
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8563 - loss: 0.3342 - val_accuracy: 0.8424 - val_loss: 0.3610
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8464 - loss: 0.3378 - val_accuracy: 0.8364 - val_loss: 0.3494
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.8689 - loss: 0.3120 - val_accuracy: 0.8470 - val_loss: 0.3435
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.8558 - loss: 0.3208 - val_accuracy: 0.8545 - val_loss: 0.3403
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.8738 - loss: 0.2956 - val_accuracy: 0.8500 - val_loss: 0.3343
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8606 - loss: 0.3035 - val_accuracy: 0.8455 - val_loss: 0.3332
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.8759 - loss: 0.2884 - val_accuracy: 0.8515 - val_loss: 0.3296
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8816 - loss: 0.2729 - val_accuracy: 0.8561 - val_loss: 0.3268
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.8701 - loss: 0.2885 - val_accuracy: 0.8545 - val_loss: 0.3215
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8846 - loss: 0.2645 - val_accuracy: 0.8576 - val_loss: 0.3199
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8743 - loss: 0.2749 - val_accuracy: 0.8652 - val_loss: 0.3170
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8839 - loss: 0.2651 - val_accuracy: 0.8515 - val_loss: 0.3293
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8867 - loss: 0.2536 - val_accuracy: 0.8636 - val_loss: 0.3125
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8787 - loss: 0.2608 - val_accuracy: 0.8545 - val_loss: 0.3128

# %%
plt.figure(figsize=(6, 4))

epochs = history_0_0001.epoch
val = history_0_0001.history['val_accuracy']
train = history_0_0001.history['accuracy']

plt.plot(epochs, val, color='black', linestyle='solid', label='validation')
plt.plot(epochs, train, color='black', linestyle='dashed', label='train')

plt.title('Xception v1, lr=0.0001')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.xticks(epochs)

plt.legend()


plt.savefig('xception_v1_0_0001.svg')

plt.show()

# %%
epochs = np.arange(20)
val_0_01 = history.history['val_accuracy']
val_0_001 = history_0_001.history['val_accuracy']
val_0_0001 = history_0_0001.history['val_accuracy']

# %%
plt.figure(figsize=(6, 4))

plt.plot(epochs, val_0_01, color='black', linestyle='solid', label='0.01')
plt.plot(epochs, val_0_001, color='black', linestyle='dashed', label='0.001')
plt.plot(epochs, val_0_0001, color='black', linestyle='dotted', label='0.0001')


plt.title('ResNet v1, different learning rates')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.xticks(epochs)

plt.legend()

plt.savefig('resnet_v1_all_lr.svg')

plt.show()

# %% [markdown]
# The best models:
#
# * learning rate 0.01: 0.8713
# * learning rate 0.001: 0.8770
# * learning rate 0.0001: 0.8470
#
# (your results may be slightly different)

# %% [markdown]
# To save the best model, we can use a callback. It'll monitor the accuracy, and if it's an improvement over the previous version, it'll save the model to disk

# %%
model = make_model(learning_rate=0.001)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "ResNet_v1_{epoch:02d}_{val_accuracy:.3f}.h5",
        monitor="val_accuracy",
        save_best_only=True,
        mode='max'
    )
]

history_0_001 = model.fit(train_ds, epochs=10, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7040 - loss: 0.6150
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 188ms/step - accuracy: 0.7049 - loss: 0.6134 - val_accuracy: 0.8439 - val_loss: 0.3570
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8514 - loss: 0.3226
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.8514 - loss: 0.3225 - val_accuracy: 0.8636 - val_loss: 0.3199
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8694 - loss: 0.2851
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.8695 - loss: 0.2851 - val_accuracy: 0.8652 - val_loss: 0.3116
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8872 - loss: 0.2426
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.8873 - loss: 0.2427 - val_accuracy: 0.8667 - val_loss: 0.3060
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8962 - loss: 0.2304
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.8961 - loss: 0.2305 - val_accuracy: 0.8833 - val_loss: 0.2947
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9147 - loss: 0.2121 - val_accuracy: 0.8682 - val_loss: 0.3046
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9084 - loss: 0.2158 - val_accuracy: 0.8621 - val_loss: 0.2991
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9172 - loss: 0.1869 - val_accuracy: 0.8561 - val_loss: 0.3508
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9309 - loss: 0.1820 - val_accuracy: 0.8652 - val_loss: 0.3157
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9347 - loss: 0.1726 - val_accuracy: 0.8833 - val_loss: 0.2865

# %% [markdown]
# Let's add one more layer - and a dropout between them

# %%
def make_model(learning_rate, droprate):
    base_model = ResNet50(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(150, 150, 3))
    
    base = base_model(inputs, training=False)
    vector = keras.layers.GlobalAveragePooling2D()(base)

    inner = keras.layers.Dense(100, activation='relu')(vector)
    drop = keras.layers.Dropout(droprate)(inner)

    outputs = keras.layers.Dense(2)(drop)

    model = keras.Model(inputs, outputs)
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    
    return model

# %%
model = make_model(learning_rate=0.001, droprate=0.0)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "ResNet_v2_0_0_{epoch:02d}_{val_accuracy:.3f}.keras",
        monitor="val_accuracy",
        save_best_only=True,
        mode='max'
    )
]

history_0 = model.fit(train_ds, epochs=30, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 25s 196ms/step - accuracy: 0.7170 - loss: 0.7837 - val_accuracy: 0.8652 - val_loss: 0.3050
# Epoch 2/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.8728 - loss: 0.2833 - val_accuracy: 0.8803 - val_loss: 0.2660
# Epoch 3/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.8953 - loss: 0.2282 - val_accuracy: 0.8894 - val_loss: 0.2565
# Epoch 4/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.9173 - loss: 0.1991 - val_accuracy: 0.8864 - val_loss: 0.2543
# Epoch 5/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9283 - loss: 0.1755 - val_accuracy: 0.8803 - val_loss: 0.2997
# Epoch 6/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9334 - loss: 0.1559 - val_accuracy: 0.8788 - val_loss: 0.2838
# Epoch 7/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9545 - loss: 0.1185 - val_accuracy: 0.8727 - val_loss: 0.2799
# Epoch 8/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9519 - loss: 0.1282 - val_accuracy: 0.8803 - val_loss: 0.2877
# Epoch 9/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.9661 - loss: 0.0992 - val_accuracy: 0.8758 - val_loss: 0.3111
# Epoch 10/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9658 - loss: 0.0826 - val_accuracy: 0.8758 - val_loss: 0.2914
# Epoch 11/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9796 - loss: 0.0688 - val_accuracy: 0.8742 - val_loss: 0.3207
# Epoch 12/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9789 - loss: 0.0657 - val_accuracy: 0.8758 - val_loss: 0.3138
# Epoch 13/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9901 - loss: 0.0466 - val_accuracy: 0.8803 - val_loss: 0.3440
# Epoch 14/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9873 - loss: 0.0402 - val_accuracy: 0.8864 - val_loss: 0.3492
# Epoch 15/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9945 - loss: 0.0269 - val_accuracy: 0.8848 - val_loss: 0.3916
# Epoch 16/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9941 - loss: 0.0265 - val_accuracy: 0.8833 - val_loss: 0.3764
# Epoch 17/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9989 - loss: 0.0148 - val_accuracy: 0.8803 - val_loss: 0.4186
# Epoch 18/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9963 - loss: 0.0196 - val_accuracy: 0.8606 - val_loss: 0.4282
# Epoch 19/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9962 - loss: 0.0159 - val_accuracy: 0.8848 - val_loss: 0.4250
# Epoch 20/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9984 - loss: 0.0082 - val_accuracy: 0.8818 - val_loss: 0.4496
# Epoch 21/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9984 - loss: 0.0076 - val_accuracy: 0.8894 - val_loss: 0.4401
# Epoch 22/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8697 - val_loss: 0.4660
# Epoch 23/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8788 - val_loss: 0.4648
# Epoch 24/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8833 - val_loss: 0.4775
# Epoch 25/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8848 - val_loss: 0.4731
# Epoch 26/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8864 - val_loss: 0.4771
# Epoch 27/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8833 - val_loss: 0.4857
# Epoch 28/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8788 - val_loss: 0.4941
# Epoch 29/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8803 - val_loss: 0.4992
# Epoch 30/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8848 - val_loss: 0.5189

# %%
model = make_model(learning_rate=0.001, droprate=0.2)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "ResNet_v2_0_2_{epoch:02d}_{val_accuracy:.3f}.keras",
        monitor="val_accuracy",
        save_best_only=True,
        mode='max'
    )
]

history_1 = model.fit(train_ds, epochs=30, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 212ms/step - accuracy: 0.7033 - loss: 0.7442 - val_accuracy: 0.8606 - val_loss: 0.3199
# Epoch 2/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.8510 - loss: 0.3020 - val_accuracy: 0.8803 - val_loss: 0.2685
# Epoch 3/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.8845 - loss: 0.2444 - val_accuracy: 0.8606 - val_loss: 0.3517
# Epoch 4/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8879 - loss: 0.2480 - val_accuracy: 0.8667 - val_loss: 0.2739
# Epoch 5/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - accuracy: 0.9018 - loss: 0.2060 - val_accuracy: 0.8818 - val_loss: 0.2513
# Epoch 6/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9161 - loss: 0.1845 - val_accuracy: 0.8788 - val_loss: 0.2839
# Epoch 7/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9186 - loss: 0.1826 - val_accuracy: 0.8833 - val_loss: 0.2726
# Epoch 8/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9301 - loss: 0.1624 - val_accuracy: 0.8955 - val_loss: 0.2612
# Epoch 9/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9465 - loss: 0.1340 - val_accuracy: 0.8742 - val_loss: 0.2727
# Epoch 10/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.9536 - loss: 0.1119 - val_accuracy: 0.8879 - val_loss: 0.2735
# Epoch 11/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9616 - loss: 0.0963 - val_accuracy: 0.8924 - val_loss: 0.2550
# Epoch 12/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9577 - loss: 0.0999 - val_accuracy: 0.8773 - val_loss: 0.2973
# Epoch 13/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9710 - loss: 0.0869 - val_accuracy: 0.8833 - val_loss: 0.3081
# Epoch 14/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.9699 - loss: 0.0857 - val_accuracy: 0.8833 - val_loss: 0.3587
# Epoch 15/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9746 - loss: 0.0725 - val_accuracy: 0.8788 - val_loss: 0.3864
# Epoch 16/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9723 - loss: 0.0705 - val_accuracy: 0.8712 - val_loss: 0.3700
# Epoch 17/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9796 - loss: 0.0628 - val_accuracy: 0.8682 - val_loss: 0.3607
# Epoch 18/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - accuracy: 0.9772 - loss: 0.0616 - val_accuracy: 0.8894 - val_loss: 0.3200
# Epoch 19/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9879 - loss: 0.0394 - val_accuracy: 0.8833 - val_loss: 0.3516
# Epoch 20/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9846 - loss: 0.0417 - val_accuracy: 0.8742 - val_loss: 0.3550
# Epoch 21/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9761 - loss: 0.0545 - val_accuracy: 0.8727 - val_loss: 0.3564
# Epoch 22/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9771 - loss: 0.0634 - val_accuracy: 0.8742 - val_loss: 0.4238
# Epoch 23/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9837 - loss: 0.0424 - val_accuracy: 0.8788 - val_loss: 0.4193
# Epoch 24/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.
30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8611 - loss: 0.2808 - val_accuracy: 0.8667 - val_loss: 0.2766
# Epoch 21/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.8481 - loss: 0.3027 - val_accuracy: 0.8773 - val_loss: 0.2710
# Epoch 22/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8464 - loss: 0.2905 - val_accuracy: 0.8758 - val_loss: 0.2725
# Epoch 23/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8638 - loss: 0.2772 - val_accuracy: 0.8712 - val_loss: 0.2791
# Epoch 24/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.8799 - loss: 0.2506 - val_accuracy: 0.8803 - val_loss: 0.2746
# Epoch 25/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8691 - loss: 0.2487 - val_accuracy: 0.8773 - val_loss: 0.2620
# Epoch 26/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.8642 - loss: 0.2710 - val_accuracy: 0.8818 - val_loss: 0.2710
# Epoch 27/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.8655 - loss: 0.2506 - val_accuracy: 0.8848 - val_loss: 0.2835
# Epoch 28/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8728 - loss: 0.2368 - val_accuracy: 0.8848 - val_loss: 0.2624
# Epoch 29/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8622 - loss: 0.2676 - val_accuracy: 0.8727 - val_loss: 0.2724
# Epoch 30/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8888 - loss: 0.2491 - val_accuracy: 0.8727 - val_loss: 0.2681

# %%
epochs = np.arange(30)

train00 = history_0.history['accuracy']
train02 = history_1.history['accuracy']
train05 = history_2.history['accuracy']
train08 = history_3.history['accuracy']

val00 = history_0.history['val_accuracy']
val02 = history_1.history['val_accuracy']
val05 = history_2.history['val_accuracy']
val08 = history_3.history['val_accuracy']

# %%
plt.figure(figsize=(6, 4))

plt.plot(epochs, val00, color='black', linestyle='dashed', label='0.0')
plt.plot(epochs, val02, color='grey', linestyle='dashed', label='0.2')
plt.plot(epochs, val05, color='black', linestyle='solid', label='0.5')
plt.plot(epochs, val08, color='grey', linestyle='solid', label='0.8')


plt.title('ResNet v2, different dropout rates')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')


plt.legend()

plt.savefig('resnet_v2_dropout.svg')

plt.show()

# %%
plt.figure(figsize=(6, 4))

plt.plot(epochs, train00, color='black', linestyle='dashed', label='0.0')
plt.plot(epochs, train02, color='grey', linestyle='dashed', label='0.2')
plt.plot(epochs, train05, color='black', linestyle='solid', label='0.5')
plt.plot(epochs, train08, color='grey', linestyle='solid', label='0.8')


plt.title('ResNet50 v2, different dropout rates (train)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')


plt.legend()

plt.savefig('resnet50_v2_dropout_train.svg')

plt.show()

# %% [markdown]
# ## Data augmentation

# %%
validation_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

val_ds = validation_gen.flow_from_directory(
    "/kaggle/input/skin-dataset/data/test",
    seed=1,
    target_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 660 images belonging to 2 classes.

# %%
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=10.0,
    zoom_range=0.1,
    horizontal_flip=True,  
)

train_ds = train_gen.flow_from_directory(
    "/kaggle/input/skin-dataset/data/train",
    seed=1,
    target_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2637 images belonging to 2 classes.

# %%
model = make_model(learning_rate=0.001, droprate=0.2)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "ResNet_v3_{epoch:02d}_{val_accuracy:.3f}.keras",
        monitor="val_accuracy",
        save_best_only=True,
        mode='max'
    )
]

history = model.fit(train_ds, epochs=50, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 311ms/step - accuracy: 0.7543 - loss: 0.5513 - val_accuracy: 0.8409 - val_loss: 0.3377
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 213ms/step - accuracy: 0.8409 - loss: 0.3326 - val_accuracy: 0.8682 - val_loss: 0.2934
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - accuracy: 0.8576 - loss: 0.2794 - val_accuracy: 0.8833 - val_loss: 0.2697
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s
50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.9638 - loss: 0.1002 - val_accuracy: 0.8970 - val_loss: 0.3301
# Epoch 31/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.9711 - loss: 0.0837 - val_accuracy: 0.8924 - val_loss: 0.3396
# Epoch 32/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 224ms/step - accuracy: 0.9721 - loss: 0.0769 - val_accuracy: 0.8879 - val_loss: 0.3456
# Epoch 33/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 224ms/step - accuracy: 0.9644 - loss: 0.0900 - val_accuracy: 0.8985 - val_loss: 0.2992
# Epoch 34/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 224ms/step - accuracy: 0.9539 - loss: 0.1105 - val_accuracy: 0.8818 - val_loss: 0.3464
# Epoch 35/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 230ms/step - accuracy: 0.9587 - loss: 0.0976 - val_accuracy: 0.8909 - val_loss: 0.3455
# Epoch 36/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.9717 - loss: 0.0790 - val_accuracy: 0.9030 - val_loss: 0.2870
# Epoch 37/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.9713 - loss: 0.0776 - val_accuracy: 0.8848 - val_loss: 0.3744
# Epoch 38/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - accuracy: 0.9730 - loss: 0.0711 - val_accuracy: 0.8924 - val_loss: 0.3445
# Epoch 39/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 228ms/step - accuracy: 0.9688 - loss: 0.0774 - val_accuracy: 0.8924 - val_loss: 0.3686
# Epoch 40/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 224ms/step - accuracy: 0.9677 - loss: 0.0828 - val_accuracy: 0.8970 - val_loss: 0.3637
# Epoch 41/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - accuracy: 0.9740 - loss: 0.0684 - val_accuracy: 0.8773 - val_loss: 0.3830
# Epoch 42/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.9644 - loss: 0.0796 - val_accuracy: 0.8955 - val_loss: 0.3582
# Epoch 43/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 227ms/step - accuracy: 0.9663 - loss: 0.0832 - val_accuracy: 0.8939 - val_loss: 0.3669
# Epoch 44/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 226ms/step - accuracy: 0.9715 - loss: 0.0740 - val_accuracy: 0.8818 - val_loss: 0.3907
# Epoch 45/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 232ms/step - accuracy: 0.9753 - loss: 0.0622 - val_accuracy: 0.8879 - val_loss: 0.4303
# Epoch 46/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 240ms/step - accuracy: 0.9735 - loss: 0.0645 - val_accuracy: 0.8803 - val_loss: 0.3854
# Epoch 47/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.9640 - loss: 0.0928 - val_accuracy: 0.8939 - val_loss: 0.4455
# Epoch 48/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - accuracy: 0.9707 - loss: 0.0747 - val_accuracy: 0.8833 - val_loss: 0.4183
# Epoch 49/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 21s 258ms/step - accuracy: 0.9733 - loss: 0.0595 - val_accuracy: 0.8833 - val_loss: 0.4039
# Epoch 50/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 23s 272ms/step - accuracy: 0.9770 - loss: 0.0629 - val_accuracy: 0.8864 - val_loss: 0.4245

# %%
epochs = history.epoch
accuracy = history.history['val_accuracy']

# %%
plt.figure(figsize=(6, 4))

plt.plot(epochs, accuracy, color='black', linestyle='solid')


plt.title('ResNet50 v3, augmentations')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.savefig('ResNet50_v3_aug.svg')

plt.show()

# %% [markdown]
# ## Larger model

# %%
def make_model(learning_rate, droprate):
    base_model = ResNet50(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(224, 224, 3))

    base = base_model(inputs, training=False)
    vector = keras.layers.GlobalAveragePooling2D()(base)

    inner = keras.layers.Dense(100, activation='relu')(vector)
    drop = keras.layers.Dropout(droprate)(inner)

    outputs = keras.layers.Dense(2)(drop)

    model = keras.Model(inputs, outputs)
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    
    return model

# %%
image_size = (224, 224)
batch_size = 32

# %%
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=10.0,
    zoom_range=0.1,
    horizontal_flip=True,  
)

train_ds = train_gen.flow_from_directory(
    "/kaggle/input/skin-dataset/data/train",
    seed=1,
    target_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2637 images belonging to 2 classes.

# %%
test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_ds = test_gen.flow_from_directory(
    "/kaggle/input/skin-dataset/data/test",
    seed=1,
    target_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 660 images belonging to 2 classes.

# %%
model = make_model(learning_rate=0.001, droprate=0.2)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "ResNet_v4_large_{epoch:02d}_{val_accuracy:.3f}.keras",
        monitor="val_accuracy",
        save_best_only=True,
        mode='max'
    )
]

history_l = model.fit(train_ds, epochs=20, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 60s 579ms/step - accuracy: 0.7573 - loss: 0.5133 - val_accuracy: 0.8712 - val_loss: 0.3023
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 395ms/step - accuracy: 0.8723 - loss: 0.2792 - val_accuracy: 0.8697 - val_loss: 0.2905
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 394ms/step - accuracy: 0.8769 - loss: 0.2684 - val_accuracy: 0.8682 - val_loss: 0.2824
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 405ms/step - accuracy: 0.8988 - loss: 0.2348 - val_accuracy: 0.8864 - val_loss: 0.3097
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.8889 - loss: 0.2364 - val_accuracy: 0.8712 - val_loss: 0.3055
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 432ms/step - accuracy: 0.8994 - loss: 0.2154 - val_accuracy: 0.8848 - val_loss: 0.2669
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 407ms/step - accuracy: 0.9178 - loss: 0.2061 - val_accuracy: 0.8985 - val_loss: 0.2530
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 388ms/step - accuracy: 0.9022 - loss: 0.2046 - val_accuracy: 0.8939 - val_loss: 0.2581
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 390ms/step - accuracy: 0.9175 - loss: 0.1931 - val_accuracy: 0.8864 - val_loss: 0.2635
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 390ms/step - accuracy: 0.9288 - loss: 0.1569 - val_accuracy: 0.8848 - val_loss: 0.2710
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 418ms/step - accuracy: 0.9324 - loss: 0.1679 - val_accuracy: 0.8833 - val_loss: 0.3070
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 417ms/step - accuracy: 0.9318 - loss: 0.1551 - val_accuracy: 0.8742 - val_loss: 0.3304
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 423ms/step - accuracy: 0.9451 - loss: 0.1419 - val_accuracy: 0.8712 - val_loss: 0.3300
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 420ms/step - accuracy: 0.9375 - loss: 0.1466 - val_accuracy: 0.8909 - val_loss: 0.2877
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 426ms/step - accuracy: 0.9422 - loss: 0.1480 - val_accuracy: 0.8909 - val_loss: 0.2990
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 428ms/step - accuracy: 0.9528 - loss: 0.1121 - val_accuracy: 0.8712 - val_loss: 0.3010
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 414ms/step - accuracy: 0.9439 - loss: 0.1346 - val_accuracy: 0.8909 - val_loss: 0.3117
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 416ms/step - accuracy: 0.9547 - loss: 0.1157 - val_accuracy: 0.8758 - val_loss: 0.3322
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 416ms/step - accuracy: 0.9537 - loss: 0.1151 - val_accuracy: 0.8879 - val_loss: 0.2961
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 418ms/step - accuracy: 0.9563 - loss: 0.1108 - val_accuracy: 0.8909 - val_loss: 0.3030

# %% [markdown]
# Let's test these models now! (see another notebook)
