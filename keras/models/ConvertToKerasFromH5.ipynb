# %%
from tensorflow import keras

# Load the .h5 model
model = keras.models.load_model('ResNet_v4_large_15_0.906.h5')

# Save it in the new .keras format
model.save('SkinCancerModel.keras')
# Out:
# 2025-12-31 13:33:00.861718: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-31 13:33:14.627409: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-31 13:33:22.862567: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# ...

# %%
from tensorflow import keras

model = keras.models.load_model('SkinCancerModel.keras')
model.export("skin_cancer_model-new_savedmodel")
# Out:
# 2025-12-31 16:48:48.517606: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-31 16:48:49.079786: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-31 16:48:50.946485: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# ...

# %%
# !python -m tf2onnx.convert \
    --saved-model skin_cancer_model-new_savedmodel \
    --opset 13 \
    --output skin_cancer_model-new.onnx
