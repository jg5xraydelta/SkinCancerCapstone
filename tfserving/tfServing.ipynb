# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
# !pip install grpcio tensorflow-serving-api==2.7.0
# Out:
# Requirement already satisfied: grpcio in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (1.76.0)
# Collecting tensorflow-serving-api==2.7.0
#   Using cached tensorflow_serving_api-2.7.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: protobuf>=3.6.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow-serving-api==2.7.0) (6.33.2)
# Requirement already satisfied: tensorflow<3,>=2.7.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow-serving-api==2.7.0) (2.20.0)
# Requirement already satisfied: typing-extensions~=4.12 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from grpcio) (4.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.4.0)
# Requirement already satisfied: packaging in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.32.5)
# Requirement already satisfied: setuptools in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.0.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.4.0)
# Requirement already satisfied: h5py>=3.11.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.10)
# Requirement already satisfied: pillow in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.45.1)
# Requirement already satisfied: rich in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (14.2.0)
# Requirement already satisfied: namex in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.1.0)
# Requirement already satisfied: optree in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.1.2)
# Downloading tensorflow_serving_api-2.7.0-py2.py3-none-any.whl (37 kB)
# Installing collected packages: tensorflow-serving-api
# Successfully installed tensorflow-serving-api-2.7.0

# %%
# !pip install keras-image-helper
# Out:
# Requirement already satisfied: keras-image-helper in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (0.0.2)
# Requirement already satisfied: numpy>=2.3.2 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from keras-image-helper) (2.4.0)
# Requirement already satisfied: pillow>=11.3.0 in /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages (from keras-image-helper) (12.0.0)

# %%
import grpc
import tensorflow as tf

# %%
from tensorflow_serving.apis import predict_pb2
from tensorflow_serving.apis import prediction_service_pb2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from tensorflow_serving.apis import predict_pb2
#       2 from tensorflow_serving.apis import prediction_service_pb2
#
# File /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages/tensorflow_serving/apis/predict_pb2.py:17
#      13 _sym_db = _symbol_database.Default()
#      16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
# ---> 17 from tensorflow_serving.apis import model_pb2 as tensorflow__serving_dot_apis_dot_model__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow_serving/apis/predict.proto',
#      22   package='tensorflow.serving',
#    (...)     26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__pb2.DESCRIPTOR,tensorflow__serving_dot_apis_dot_model__pb2.DESCRIPTOR,])
#      32 _PREDICTREQUEST_INPUTSENTRY = _descriptor.Descriptor(
#      33   name='InputsEntry',
#      34   full_name='tensorflow.serving.PredictRequest.InputsEntry',
#    (...)     66   serialized_end=365,
#      67 )
#
# File /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages/tensorflow_serving/apis/model_pb2.py:38
#      16 from google.protobuf import wrappers_pb2 as google_dot_protobuf_dot_wrappers__pb2
#      19 DESCRIPTOR = _descriptor.FileDescriptor(
#      20   name='tensorflow_serving/apis/model.proto',
#      21   package='tensorflow.serving',
#    (...)     25   ,
#      26   dependencies=[google_dot_protobuf_dot_wrappers__pb2.DESCRIPTOR,])
#      31 _MODELSPEC = _descriptor.Descriptor(
#      32   name='ModelSpec',
#      33   full_name='tensorflow.serving.ModelSpec',
#      34   filename=None,
#      35   file=DESCRIPTOR,
#      36   containing_type=None,
#      37   fields=[
# ---> 38     _descriptor.FieldDescriptor(
#      39       name='name', full_name='tensorflow.serving.ModelSpec.name', index=0,
#      40       number=1, type=9, cpp_type=9, label=1,
#      41       has_default_value=False, default_value=_b("").decode('utf-8'),
#      42       message_type=None, enum_type=None, containing_type=None,
#      43       is_extension=False, extension_scope=None,
#      44       serialized_options=None, file=DESCRIPTOR),
#      45     _descriptor.FieldDescriptor(
#      46       name='version', full_name='tensorflow.serving.ModelSpec.version', index=1,
#      47       number=2, type=11, cpp_type=10, label=1,
#      48       has_default_value=False, default_value=None,
#      49       message_type=None, enum_type=None, containing_type=None,
#      50       is_extension=False, extension_scope=None,
#      51       serialized_options=None, file=DESCRIPTOR),
#      52     _descriptor.FieldDescriptor(
#      53       name='version_label', full_name='tensorflow.serving.ModelSpec.version_label', index=2,
#      54       number=4, type=9, cpp_type=9, label=1,
#      55       has_default_value=False, default_value=_b("").decode('utf-8'),
#      56       message_type=None, enum_type=None, containing_type=None,
#      57       is_extension=False, extension_scope=None,
#      58       serialized_options=None, file=DESCRIPTOR),
#      59     _descriptor.FieldDescriptor(
#      60       name='signature_name', full_name='tensorflow.serving.ModelSpec.signature_name', index=3,
#      61       number=3, type=9, cpp_type=9, label=1,
#      62       has_default_value=False, default_value=_b("").decode('utf-8'),
#      63       message_type=None, enum_type=None, containing_type=None,
#      64       is_extension=False, extension_scope=None,
#      65       serialized_options=None, file=DESCRIPTOR),
#      66   ],
#      67   extensions=[
#      68   ],
#      69   nested_types=[],
#      70   enum_types=[
#      71   ],
#      72   serialized_options=None,
#      73   is_extendable=False,
#      74   syntax='proto3',
#      75   extension_ranges=[],
#      76   oneofs=[
#      77     _descriptor.OneofDescriptor(
#      78       name='version_choice', full_name='tensorflow.serving.ModelSpec.version_choice',
#      79       index=0, containing_type=None, fields=[]),
#      80   ],
#      81   serialized_start=92,
#      82   serialized_end=232,
#      83 )
#      85 _MODELSPEC.fields_by_name['version'].message_type = google_dot_protobuf_dot_wrappers__pb2._INT64VALUE
#      86 _MODELSPEC.oneofs_by_name['version_choice'].fields.append(
#      87   _MODELSPEC.fields_by_name['version'])
#
# File /workspaces/SkinCancerCapstone/.venv/lib/python3.13/site-packages/google/protobuf/descriptor.py:675, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     652 def __new__(
#     653     cls,
#     654     name,
#    (...)    673     create_key=None,
#     674 ):  # pylint: disable=redefined-builtin
# --> 675   _message.Message._CheckCalledFromGeneratedFile()
#     676   if is_extension:
#     677     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
